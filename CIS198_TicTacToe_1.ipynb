# %% [markdown]
# <a href="https://colab.research.google.com/github/Yhannah3/Yhannah3.github.io/blob/main/CIS198_TicTacToe_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tic Tac Toe Python
#
# In this assignment, you will be creating a program to play Tic Tac Toe.
#
# YOU MUST TYPE YOUR OWN CODE. YOU MAY NOT USE GENERATIVE AI WITHIN COLAB. YOU MAY USE chatgpt/gemini/google search FOR LOOKING UP HELP.

# %% [markdown]
# ### The str join() method
#
# If we have a list, we can concatenate the list elements with the join method/
#     a = [I', 'like', 'chicken']
#     print(''.join(a))
#
# The above will merge ''I', 'like' and 'chicken'

# %% [markdown]
# ### Representing a board (game state)
#
# We can use a 9 element list to represent a tic tac toe board, with each element being one of '-', 'X', 'O'. The first element of the list represents the top left, the second element the top middle, the third the top right, the fourth, the middle row left, etc.
#
# Here is an empty board (i.e. at the start of a game):
#
#     board = ['-', '-', '-',  '-', '-', '-', '-', '-', '-']
#
# Here is a board after X goes in the middle:
#
#     board = ['-', '-', '-',  '-', 'X', '-', '-', '-', '-']
#
#
# To set the top left element to an X, we do the following:
#
#     board[0] = 'X'
#
# To print out the top row of the board, we can use the following:
#
#     print(board[0:3])
#
# To print out the top row of the board with the elements of the list separated by a '|', we can use the join str method.
#
#     print('|'.join(board[0:3))
#
#
# We can check if a variable is a list using the type() function.
#
#     x = 5
#     print('board is a list: ', type(board) == list)
#     print('x is a list: ', type(x) == list)

# %% [markdown]
# QUESTION 1: In the code cell below, complete the function so that it prints out the top row, middle row, and then bottom row of the board, separating each cell with a '|'.  Add a check

# %%
def print_board(b):
  """ Checks whether b is a list, prints error message and returns if not
      prints the top row with each element separated by a verical bar |
      prints the middle row with each element separated by a verical bar |
      prints the bottom row with each element separated by a verical bar |
       """
  print('board is a list: ', type(b) == list)
  b = ['-', '-', '-',  '-', '-', '-', '-', '-', '-']

# %%
x=5
print('x is a list: ', type(x) ==list)
# Out:
# x is a list:  False

# %%
x = 5
x= [2.3]
print(type(x))
if type(x) == list:
  print('x is a list!')
else:
  print('x is NOT a list')
if type(x) == int:
  print('x is an int!')
else:
  print('x is not an int!')
# Out:
# <class 'list'>
# x is a list!
# x is not an int!

# %%
x = 5       # int
a = [6.5]   #list

if type(x) == list:
  print('x is a list')

if type(x) != list:
  print('x is not a list')
# Out:
# x is not a list

# %%
def print_board(b):
  if type(b) != list:
    print('error')
    return
  print('|'.join(b[0:3]))
  print('|'.join(b[3:6]))
  print('|'.join(b[6:9]))


print_board(b)
print('board is a list: ', type(b) == list)
b1 = ['-', '-', '-',
      '-', '-', '-',
      '-', '-', '-']


b1 = ['X', 'O', 'X',
      '-', '-', '-',
      '-', '-', '-']

print_board(b1)
# Out:
# X|-|-
# -|-|-
# -|-|-
# board is a list:  True
# X|O|X
# -|-|-
# -|-|-

# %% [markdown]
# QUESITON 2: Write code below that creates an empty Tic Tac Toe board variable b, then asks the user where they want to go by entering a number 0 to 8, then sets the board at that position to 'X'.

# %%
b = ['-', '-', '-', '-', '-', '-', '-', '-', '-']

pos = int(input("Enter a position (0-8): "))
b[pos] = 'X'

print_board(b)
# Out:
# Enter a position (0-8): 0
# board is a list:  True

# %% [markdown]
# QUESTION 3: Copy your code above to the cell below. Add a loop so that on each turn, it alternates between adding an X and a 'O'

# %%
b = ['-', '-', '-', '-', '-', '-', '-', '-', '-']

for turn in range(9):
  pos = int(input("Enter a position (0-8): "))

  if turn % 2 == 0:
    b[pos] = 'X'
  else:
    b[pos] = 'O'

  print_board(b)
# Out:
# Enter a position (0-8): 7
# -|-|-
# -|-|-
# -|X|-
# Enter a position (0-8): 5
# -|-|-
# -|-|O
# -|X|-
# Enter a position (0-8): 8
# -|-|-
# -|-|O
# -|X|X
# Enter a position (0-8): 4
# -|-|-
# -|O|O
# -|X|X
# Enter a position (0-8): 6
# -|-|-
# -|O|O
# X|X|X

# %% [markdown]
# QUESTION 4: Copy your code from above to the cell below. Before accepting a player's move, check that the cell that they want to go in is empty (i.e. == '-'), and if not empty, checks again.

# %%
b = ['-', '-', '-', '-', '-', '-', '-', '-', '-']

for turn in range(9):
  while True:
    pos = int(input("Enter a position (0-8): "))

    if b[pos] == '-':
      break
    else:
      print("That spot is taken! Try again.")

  if turn % 2 == 0:
    b[pos] = 'X'
  else:
    b[pos] = 'O'

  print_board(b)

# %% [markdown]
# 3/12

# %%
# Out:
#   File "/tmp/ipykernel_3425/2208405268.py", line 3
#     while i < len(a)
#                     ^
# SyntaxError: expected ':'
