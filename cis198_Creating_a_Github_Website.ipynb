# %% [markdown]
# <a href="https://colab.research.google.com/github/Yhannah3/Yhannah3.github.io/blob/main/cis198_Creating_a_Github_Website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## How to Display images
# [my school]("https:niagara.edu")
# ![my meme](Assignment 1 Meme.jpg)
# ![my meme](https://github.com/Yhannah3/Yhannah3.github.io/blob/30cfc3b07b2afd6c9b99de5753832619029ae872/Assignment%201%20Meme%20(1).jpg)

# %% [markdown]
# In this notebook we will have notes on Markdown, HTML, and creating a website on github.com

# %% [markdown]
# 1. Google search (or another search provider).
#   *SEARCH: "how to create a website hosted on github.com"
# 1. Ask a LLM(large language model i.e. chatgpt).
#   *PROMPT: "how to create a website hosted on github.com"

# %% [markdown]
# ### github notes
#
# key terms:
# * **repository** - a container holding all *committed* files, and folders.
# * **commit** - saving a file version in a respository(along with a save message, i.e. commit message)
# * **git** - version control program (i.e. a app for saving many versions of files, ex. computer code.)
# * **github.com** - a online company (website) providing a place for users to save their  repositories.

# %% [markdown]
# ### google search notes
#
# **double quotes** - when you put words or phrases in double quotes, this *forces* google to return only pages that have the actual *string* in double quotes
#
# **site:github.com** - using the *site:* keyword limits the search results to the domain name (URL) provided.
#
# example: to search for pages about tourism on niagara's website you use the search phrase:
#
#     site:niagara.edu tourism

# %% [markdown]
# ### Python notes
#
# data types
#
#
# **str** - a string of characters (letters/numbers/punctuation)
#
#
# **int** - an integer (no size limit)
#
#
# **float** - a floating point number
# (i.e. decimal, like scientific notation)
#
#
# **bool** - a True/False, i.e. Boolean

# %% [markdown]
# ### Markdown notes
#
# Markdown is a simple markup language, known for being easy to read in its raw text format and simple options.
#
# Heading
#
#     # heading title
#
# If you lead your text with four space (and you have a newline above and below) it will go into *code format* which uses monospace font and syntax highlighting.

# %% [markdown]
# ## Welcome to Hannah's website.
#
# TODO: Insert picture of me (or cartoon render)
#
# []("../Hannah Pic.jpg")
#
# I work at: [Niagara University](https://niagara.edu)
# Classes that I take:
# *CIS 198: Comp Ed.
# *.
# *
#
# Fun projects:
# * Creating music with AI. (click here to hear my latest AI generated music track).
